# %% [markdown]
# <a href="https://colab.research.google.com/github/Twenkid/NLP-Computational-Linguistics/blob/main/DeepPavlov-3-2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deeppavlov
# Out:
# ...
#      |████████████████████████████████| 880 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 76 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 43 kB 726 kB/s
# ...
#      |████████████████████████████████| 859 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 10.4 MB 19.5 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 37.9 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 36.5 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 42.2 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 37.7 MB/s
# ...
#      |████████████████████████████████| 40 kB 22 kB/s
# ...
#      |████████████████████████████████| 654 kB 32.6 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 33.2 MB/s
# ...
#      |████████████████████████████████| 8.2 MB 28.3 MB/s
# ...

# %%
# !python -m deeppavlov install ner_ontonotes_bert_torch
# Out:
# 2022-03-03 23:19:01.566 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'ner_ontonotes_bert_torch' as '/usr/local/lib/python3.7/dist-packages/deeppavlov/configs/ner/ner_ontonotes_bert_torch.json'
# ...
#      |████████████████████████████████| 748.8 MB 18 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.6.0 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.6.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.6.0 which is incompatible.
# ...
#      |████████████████████████████████| 5.9 MB 5.6 MB/s
# ...

# %%
from deeppavlov import configs, build_model

ner_model = build_model(configs.ner.ner_ontonotes_bert_torch, download=True)

ner_model(['Bob Ross lived in Florida'])
# Out:
# /usr/local/lib/python3.7/dist-packages/cryptography/hazmat/backends/openssl/x509.py:17: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   utils.DeprecatedIn35,
# 2022-03-04 00:10:07.678 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/v1/ner/ner_ontonotes_bert_torch.tar.gz to /root/.deeppavlov/ner_ontonotes_bert_torch.tar.gz
# 100%|██████████| 1.12G/1.12G [00:42<00:00, 26.2MB/s]
# 2022-03-04 00:10:51.459 INFO in 'deeppavlov.core.data.utils'['utils'] at line 272: Extracting /root/.deeppavlov/ner_ontonotes_bert_torch.tar.gz archive into /root/.deeppavlov/models
# ...

# %%
ner_model(['Иван Драганов се разходи в Пловдив и посети Макдоналдс през 1945 г.'])

# %%
ner_model(['Иван Драганов се разходи в Пловдив и посети Макдоналдс през 1945 г.'])
# Out:
# [[['Иван',
#    'Драганов',
#    'се',
#    'разходи',
#    'в',
#    'Пловдив',
#    'и',
#    'посети',
#    'Макдоналдс',
#    'през',
#    '1945',
#    'г',
#    '.']],
#  [['B-PERSON',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-DATE',
#    'O',
#    'O']]]
